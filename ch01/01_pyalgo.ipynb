# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Algorithmic Trading
#
# **Chapter 01 &mdash; Python and Algorithmic Trading**

# %%
# %%time
import random
from math import exp, sqrt

S0 = 100
r = 0.05
T = 1.0
sigma = 0.2

values = []

for _ in range(1000000):
    ST = S0 * exp((r - 0.5 * sigma ** 2) * T +
                    sigma * random.gauss(0, 1) * sqrt(T))
    values.append(ST)
# Out:
# CPU times: user 597 ms, sys: 8.18 ms, total: 605 ms
# Wall time: 606 ms

# %%
# %%time
import numpy as np

S0 = 100
r = 0.05
T = 1.0
sigma = 0.2

ST = S0 * np.exp((r - 0.5 * sigma ** 2) * T +
                    sigma * np.random.standard_normal(1000000) * np.sqrt(T))
# Out:
# CPU times: user 140 ms, sys: 23.4 ms, total: 164 ms
# Wall time: 113 ms

# %%
# %matplotlib inline
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'

# %%
import configparser
c = configparser.ConfigParser()
c.read('../pyalgo_example.cfg')
# Out:
# ['../pyalgo_example.cfg']

# %%
import quandl as q
q.ApiConfig.api_key = 'pzrz3hUJWn3Ay6GLVz-W'
d = q.get('BCHAIN/MKPRU')

d['SMA'] = d['Value'].rolling(100).mean()
d.loc['2013-1-1':].plot(title='BTC/USD exchange rate',
                        figsize=(10, 6))
plt.savefig('../images/ch01_bitcoin_xr.png')

# %%
d.tail()
# Out:
#                Value         SMA
# Date
# 2022-03-16  39320.82  42786.5697
# 2022-03-17  41133.08  42692.2542
# 2022-03-18  40946.78  42595.2679
# 2022-03-19  41795.77  42508.1144
# 2022-03-20  42222.32  42453.7408

# %% [markdown]
# 其他東西

# %%
import datetime 
start_date = datetime()
end_date = 
df = q.get('CHRIS/CME_CL1', start_date=start, end_date=end, collapse="daily") # daily為資料頻率

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
